# %% [markdown]
# ## Load Census Zip Code Shapes

# %% [markdown]
# ### Set Up

# %%
pip install pandas -q
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.3.4_1/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install openpyxl -q
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.3.4_1/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install geopandas -q
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.3.4_1/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install matplotlib -q
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.3.4_1/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install folium -q
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.3.4_1/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install branca -q
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.3.4_1/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install h3 -q
# Out:
# [notice] A new release of pip is available: 25.2 -> 26.0.1
# [notice] To update, run: /opt/homebrew/Cellar/jupyterlab/4.3.4_1/libexec/bin/python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)

import warnings
warnings.filterwarnings('ignore')

import geopandas as gpd
import matplotlib.pyplot as plt

import folium
from folium import plugins
import matplotlib.cm as cm 
import matplotlib.colors as colors
from branca.element import Element

import h3

# %% [markdown]
# ### Load Data

# %%
shapefile = "/Users/haley.northrup/Documents/PeopleCenteredCOS/zip_code_data/Census_ZIP_Code_Tabulation_Areas.shp"
shapefile_gdf = gpd.read_file(shapefile)
shapefile_gdf.head()
# Out:
#              ObjID  ZCTA5  GEOID BASENAME LSADC         NAME ZCTA5CC  MTFCC  \
# 0  221704258442791  83554  83554    83554    Z5  ZCTA5 83554      B5  G6350
# 1  221704258439048  83442  83442    83442    Z5  ZCTA5 83442      B5  G6350
# 2  221704258443951  83611  83611    83611    Z5  ZCTA5 83611      B5  G6350
# 3  221704258444429  83617  83617    83617    Z5  ZCTA5 83617      B5  G6350
# 4  221704258435875  83341  83341    83341    Z5  ZCTA5 83341      B5  G6350
#
#   FUNCSTAT    AREALAND AREAWATER      CENTLAT       CENTLON     INTPTLAT  \
# 0        S   563863062   4088018  +45.6851943  -116.2994534  +45.6882058
# 1        S   335226513   4550696  +43.6293058  -111.8248307  +43.6287114
# 2        S  6937946791  99471818  +45.0373418  -115.2499033  +45.3438729
# 3        S   580079602   9437999  +43.9330249  -116.5037366  +43.9368188
# 4        S   220626876   1117466  +42.4286019  -114.3705436  +42.4355495
#
#        INTPTLON   HU100   POP100  \
# ...

# %%
# Colorado Specific 
shapefile_CO = "/Users/haley.northrup/Documents/PeopleCenteredCOS/zip_code_data/Place_Data_2020.shp"
shapefile_CO_gdf = gpd.read_file(shapefile)
shapefile_CO_gdf.head()
# Out:
#              ObjID  ZCTA5  GEOID BASENAME LSADC         NAME ZCTA5CC  MTFCC  \
# 0  221704258442791  83554  83554    83554    Z5  ZCTA5 83554      B5  G6350
# 1  221704258439048  83442  83442    83442    Z5  ZCTA5 83442      B5  G6350
# 2  221704258443951  83611  83611    83611    Z5  ZCTA5 83611      B5  G6350
# 3  221704258444429  83617  83617    83617    Z5  ZCTA5 83617      B5  G6350
# 4  221704258435875  83341  83341    83341    Z5  ZCTA5 83341      B5  G6350
#
#   FUNCSTAT    AREALAND AREAWATER      CENTLAT       CENTLON     INTPTLAT  \
# 0        S   563863062   4088018  +45.6851943  -116.2994534  +45.6882058
# 1        S   335226513   4550696  +43.6293058  -111.8248307  +43.6287114
# 2        S  6937946791  99471818  +45.0373418  -115.2499033  +45.3438729
# 3        S   580079602   9437999  +43.9330249  -116.5037366  +43.9368188
# 4        S   220626876   1117466  +42.4286019  -114.3705436  +42.4355495
#
#        INTPTLON   HU100   POP100  \
# ...

# %%
shapefile_CO_gdf.head(10).explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
# ...

# %%
shapefile_CO_gdf.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 33791 entries, 0 to 33790
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   ObjID      33791 non-null  object
#  1   ZCTA5      33791 non-null  object
#  2   GEOID      33791 non-null  object
#  3   BASENAME   33791 non-null  object
#  4   LSADC      33791 non-null  object
#  5   NAME       33791 non-null  object
#  6   ZCTA5CC    33791 non-null  object
#  7   MTFCC      33791 non-null  object
#  8   FUNCSTAT   33791 non-null  object
#  9   AREALAND   33791 non-null  object
#  10  AREAWATER  33791 non-null  object
#  11  CENTLAT    33791 non-null  object
#  12  CENTLON    33791 non-null  object
#  13  INTPTLAT   33791 non-null  object
#  14  INTPTLON   33791 non-null  object
#  15  HU100      33791 non-null  float64
#  16  POP100     33791 non-null  float64
#  17  geometry   33791 non-null  geometry
# dtypes: float64(2), geometry(1), object(15)
# ...

# %%
import numpy as np 

elpaso_co_zips = np.linspace(80901, 80952, 52).astype(int).astype(str)
print(elpaso_co_zips)
    
filtered = shapefile_CO_gdf.loc[shapefile_CO_gdf['GEOID'].isin(elpaso_co_zips)]

filtered.explore()
# Out:
# ['80901' '80902' '80903' '80904' '80905' '80906' '80907' '80908' '80909'
#  '80910' '80911' '80912' '80913' '80914' '80915' '80916' '80917' '80918'
#  '80919' '80920' '80921' '80922' '80923' '80924' '80925' '80926' '80927'
#  '80928' '80929' '80930' '80931' '80932' '80933' '80934' '80935' '80936'
#  '80937' '80938' '80939' '80940' '80941' '80942' '80943' '80944' '80945'
#  '80946' '80947' '80948' '80949' '80950' '80951' '80952']
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
# ...
